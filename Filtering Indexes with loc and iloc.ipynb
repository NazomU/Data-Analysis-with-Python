# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\nazom\OneDrive\Documents\Python Scripts\Pandas Folder\WorldContinents.csv', encoding = 'ISO-8859-1')
pd.set_option('display.max.rows',1350)
pd.set_option('display.max.columns',15)

# %%
df
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...

# %%
df.loc[0]
# Out:
# continent              Asia
# sub_region    Southern Asia
# country         Afghanistan
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# continent              Asia
# sub_region    Southern Asia
# country         Afghanistan
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: 0, dtype: object

# %%
#loc is a a name based index while iloc is intger based index

# %%
df.set_index(['country'], inplace = True)

# %%
df
# Out:
#                                                    continent  \
# country
# Afghanistan                                             Asia
# Åland Islands                                         Europe
# Albania                                               Europe
# Algeria                                               Africa
# American Samoa                                       Oceania
# Andorra                                               Europe
# Angola                                                Africa
# Anguilla                                            Americas
# Antigua and Barbuda                                 Americas
# Argentina                                           Americas
# Armenia                                                 Asia
# Aruba                                               Americas
# Australia                                            Oceania
# Austria                                               Europe
# ...

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.loc['Afghanistan']
# Out:
# continent              Asia
# sub_region    Southern Asia
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: Afghanistan, dtype: object

# %%
df.iloc[0]
# Out:
# continent              Asia
# sub_region    Southern Asia
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: Afghanistan, dtype: object

# %%
df.iloc[1]
# Out:
# continent              Europe
# sub_region    Northern Europe
# code_3                    ALA
# Unnamed: 4         5,500,000
# Name: Åland Islands, dtype: object

# %%
#if we dont want to name it, we use iloc

# %%
df.reset_index(inplace = True)

# %%
df.set_index('continent', inplace = True)

# %%
df
# Out:
#                                                      country  \
# continent
# Asia                                             Afghanistan
# Europe                                         Åland Islands
# Europe                                               Albania
# Africa                                               Algeria
# Oceania                                       American Samoa
# Europe                                               Andorra
# Africa                                                Angola
# Americas                                            Anguilla
# Americas                                 Antigua and Barbuda
# Americas                                           Argentina
# Asia                                                 Armenia
# Americas                                               Aruba
# Oceania                                            Australia
# Europe                                               Austria
# ...

# %%
df.loc['Asia']
# Out:
#                                            country          sub_region code_3  \
# continent
# Asia                                   Afghanistan       Southern Asia    AFG
# Asia                                       Armenia        Western Asia    ARM
# Asia                                    Azerbaijan        Western Asia    AZE
# Asia                                       Bahrain        Western Asia    BHR
# Asia                                    Bangladesh       Southern Asia    BGD
# Asia                                        Bhutan       Southern Asia    BTN
# Asia                             Brunei Darussalam  South-Eastern Asia    BRN
# Asia                                      Cambodia  South-Eastern Asia    KHM
# Asia                                         China        Eastern Asia    CHN
# Asia                                        Cyprus        Western Asia    CYP
# Asia                                       Georgia        Western Asia    GEO
# ...

# %%
df.iloc[0]
# Out:
# country         Afghanistan
# sub_region    Southern Asia
# code_3                  AFG
# Unnamed: 4       6,900,000
# Name: Asia, dtype: object

# %%
df.reset_index(inplace = True)

# %%
df_continent = df.set_index(['continent', 'sub_region'])

# %%
df_continent
# Out:
#                                                                                country  \
# continent sub_region
# Asia      Southern Asia                                                    Afghanistan
# Europe    Northern Europe                                                Åland Islands
#           Southern Europe                                                      Albania
# Africa    Northern Africa                                                      Algeria
# Oceania   Polynesia                                                     American Samoa
# Europe    Southern Europe                                                      Andorra
# Africa    Middle Africa                                                         Angola
# Americas  Caribbean                                                           Anguilla
#           Caribbean                                                Antigua and Barbuda
# ...

# %%
df_continent.loc['Asia','Southern Asia']
# Out:
# C:\Users\nazom\AppData\Local\Temp/ipykernel_12044/389584776.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df_continent.loc['Asia','Southern Asia']
#                                             country code_3       Unnamed: 4
# continent sub_region
# Asia      Southern Asia                 Afghanistan    AFG       6,900,000
#           Southern Asia                  Bangladesh    BGD       2,500,000
#           Southern Asia                      Bhutan    BTN         771,000
#           Southern Asia                       India    IND   1,400,000,000
#           Southern Asia  Iran (Islamic Republic of)    IRN      84,000,000
#           Southern Asia                    Maldives    MDV         540,000
#           Southern Asia                       Nepal    NPL      44,000,000
#           Southern Asia                    Pakistan    PAK     331,000,000
#           Southern Asia                   Sri Lanka    LKA      33,000,000

# %%
df_continent.iloc[0]
# Out:
# country       Afghanistan
# code_3                AFG
# Unnamed: 4     6,900,000
# Name: (Asia, Southern Asia), dtype: object

# %%
df_continent.iloc[0,0]
# Out:
# 'Afghanistan'

# %%
#Reordering and sorting indexes

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      index continent                                            country  \
# 0        0      Asia                                        Afghanistan
# 1        1    Europe                                      Åland Islands
# 2        2    Europe                                            Albania
# 3        3    Africa                                            Algeria
# 4        4   Oceania                                     American Samoa
# 5        5    Europe                                            Andorra
# 6        6    Africa                                             Angola
# 7        7  Americas                                           Anguilla
# 8        8  Americas                                Antigua and Barbuda
# 9        9  Americas                                          Argentina
# 10      10      Asia                                            Armenia
# 11      11  Americas                                              Aruba
# ...

# %%
df.set_index(['continent']).sort_index()
# Out:
#            index                                            country  \
# continent
# Africa       119                                              Libya
# Africa       134                                          Mauritius
# Africa       133                                         Mauritania
# Africa       129                                               Mali
# Africa       126                                             Malawi
# Africa       125                                         Madagascar
# Africa       238                                             Zambia
# Africa       118                                            Liberia
# Africa       117                                            Lesotho
# Africa       108                                              Kenya
# Africa        87                                      Guinea-Bissau
# Africa        86                                             Guinea
# Africa        77                                              Ghana
# ...

# %%
df.set_index(['continent','sub_region']).sort_index()
# Out:
#                                      index  \
# continent sub_region
# Africa    Eastern Africa                33
#           Eastern Africa                44
#           Eastern Africa                56
#           Eastern Africa                63
#           Eastern Africa                65
#           Eastern Africa               108
#           Eastern Africa               125
#           Eastern Africa               126
#           Eastern Africa               134
#           Eastern Africa               135
#           Eastern Africa               144
#           Eastern Africa               173
#           Eastern Africa               176
#           Eastern Africa               190
#           Eastern Africa               197
#           Eastern Africa               199
#           Eastern Africa               211
#           Eastern Africa               223
#           Eastern Africa               238
#           Eastern Africa               239
# ...

# %%
df.set_index(['continent','sub_region']).sort_index(level = 'sub_region')
# Out:
#                                      index  \
# continent sub_region
# Oceania   Australia and New Zealand     12
#           Australia and New Zealand    151
#           Australia and New Zealand    156
# Americas  Caribbean                      7
#           Caribbean                      8
#           Caribbean                     11
#           Caribbean                     15
#           Caribbean                     18
#           Caribbean                     26
#           Caribbean                     38
#           Caribbean                     51
#           Caribbean                     52
#           Caribbean                     57
#           Caribbean                     58
#           Caribbean                     81
#           Caribbean                     82
#           Caribbean                     89
#           Caribbean                    103
#           Caribbean                    132
#           Caribbean                    142
# ...

# %%
df.set_index(['continent','sub_region'], inplace = True)

# %%
df
# Out:
#                                      index  \
# continent sub_region
# Asia      Southern Asia                  0
# Europe    Northern Europe                1
#           Southern Europe                2
# Africa    Northern Africa                3
# Oceania   Polynesia                      4
# Europe    Southern Europe                5
# Africa    Middle Africa                  6
# Americas  Caribbean                      7
#           Caribbean                      8
#           South America                  9
# Asia      Western Asia                  10
# Americas  Caribbean                     11
# Oceania   Australia and New Zealand     12
# Europe    Western Europe                13
# Asia      Western Asia                  14
# Americas  Caribbean                     15
# Asia      Western Asia                  16
#           Southern Asia                 17
# Americas  Caribbean                     18
# Europe    Eastern Europe                19
# ...

# %%
df.swaplevel('continent','sub_region')
# Out:
#                                      index  \
# sub_region                continent
# Southern Asia             Asia           0
# Northern Europe           Europe         1
# Southern Europe           Europe         2
# Northern Africa           Africa         3
# Polynesia                 Oceania        4
# Southern Europe           Europe         5
# Middle Africa             Africa         6
# Caribbean                 Americas       7
#                           Americas       8
# South America             Americas       9
# Western Asia              Asia          10
# Caribbean                 Americas      11
# Australia and New Zealand Oceania       12
# Western Europe            Europe        13
# Western Asia              Asia          14
# Caribbean                 Americas      15
# Western Asia              Asia          16
# Southern Asia             Asia          17
# Caribbean                 Americas      18
# Eastern Europe            Europe        19
# ...

# %%
#Reshaping and Pivoting Indexes: Stocking combines multiple columns into a single column and adds a new index level while unstocking splits a single column into multiple columns.

# %%
df = pd.read_csv(r'C:\Users\nazom\OneDrive\Documents\Python Scripts\Pandas Folder\WorldContinents.csv', encoding = 'ISO-8859-1')
pd.set_option('display.max.rows',1350)
pd.set_option('display.max.columns',15)

# %%
df
# Out:
#     continent                 sub_region  \
# 0        Asia              Southern Asia
# 1      Europe            Northern Europe
# 2      Europe            Southern Europe
# 3      Africa            Northern Africa
# 4     Oceania                  Polynesia
# 5      Europe            Southern Europe
# 6      Africa              Middle Africa
# 7    Americas                  Caribbean
# 8    Americas                  Caribbean
# 9    Americas              South America
# 10       Asia               Western Asia
# 11   Americas                  Caribbean
# 12    Oceania  Australia and New Zealand
# 13     Europe             Western Europe
# 14       Asia               Western Asia
# 15   Americas                  Caribbean
# 16       Asia               Western Asia
# 17       Asia              Southern Asia
# 18   Americas                  Caribbean
# 19     Europe             Eastern Europe
# 20     Europe             Western Europe
# 21   Americas            Central America
# ...
